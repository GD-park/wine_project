# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

 
df = pd.read_csv('final_preprocessing.csv')


data_pool = np.array(df.ix[:,1:])
x_new = data_pool[2]

distance = np.linalg.norm(data_pool - x_new, axis=1)
df['distance_2']=distance

cosine = cosine_similarity(data_pool, x_new)
df['cosine_2']=cosine

 
df.to_csv('result_add_cosinedistance.csv')
# Out:
# c:\python27\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
df1 = pd.read_csv('result_add_cosinedistance.csv')
df1.tail()
# Out:
#        Unnamed: 0     id  new_old  type  sweet  body  fruits  nuts  flowers  \
# 10341       10341  61670        0     1      4     4       3     0        0
# 10342       10342  61671        1     1      5     5       0     0        0
# 10343       10343  61672        0     1      5     4       2     0        0
# 10344       10344  61673        0     1      5     5       3     0        0
# 10345       10345  61674        0     1      5     5       2     0        0
#
#        snacks    ...     Carmenere  Riesling  Nebbiolo  Mourvedre  Moscato  \
# 10341       0    ...             0         0         0          0        0
# 10342       0    ...             0         0         0          0        0
# 10343       0    ...             0         0         0          0        0
# 10344       0    ...             0         0         0          0        0
# 10345       0    ...             0         0         0          0        0
#
#        Semillon  Viognier   1/n  distance_2  cosine_2
# ...
